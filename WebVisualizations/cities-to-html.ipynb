# %%
import pandas as pd

# %%
# Read the csv file in
df = pd.read_csv('Resources/cities.csv')

# %%
df
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0             Faanui -16.48 -151.75     80.40        77          68
# 1        Antofagasta -23.65  -70.40     60.80        72          90
# 2           Øksfjord  70.24   22.35     35.60        73           0
# 3          Jamestown  42.10  -79.24     45.00        93          90
# 4    Havre-St-Pierre  50.23  -63.60     32.00        80          90
# ..               ...    ...     ...       ...       ...         ...
# 579            Rønne  55.10   14.71     51.80       100         100
# 580         Urubichá -15.38  -62.95     70.75        97         100
# 581           Yulara -25.24  130.99     64.40        27           0
# 582         Tongzhou  39.91  116.60     57.00        55           0
# 583           Nicoya  10.15  -85.45     76.89        92          98
#
#      Wind Speed Country        Date
# 0         17.83      PF  1603752984
# 1         13.87      CL  1603753336
# 2         13.87      NO  1603753473
# ...

# %%
# Save to file
df.to_html('data.html', index=False)

# %%
# Assign to string
table = df.to_html()
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Faanui</td>
#       <td>-16.48</td>
#       <td>-151.75</td>
#       <td>80.40</td>
#       <td>77</td>
#       <td>68</td>
#       <td>17.83</td>
#       <td>PF</td>
#       <td>1603752984</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Antofagasta</td>
#       <td>-23.65</td>
#       <td>-70.40</td>
#       <td>60.80</td>
#       <td>72</td>
#       <td>90</td>
#       <td>13.87</td>
#       <td>CL</td>
#       <td>1603753336</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Øksfjord</td>
#       <td>70.24</td>
#       <td>22.35</td>
#       <td>35.60</td>
# ...
